# %%
import pandas as pd
import re
import spacy   
nlp = spacy.load('en_core_web_sm')

# %%
df = pd.read_csv("tweets_grouped.csv")

# %%
import re,string

def strip_links(text):
    link_regex    = re.compile('((https?):((//)|(\\\\))+([\w\d:#@%/;$()~_?\+-=\\\.&](#!)?)*)', re.DOTALL)
    links         = re.findall(link_regex, text)
    for link in links:
        text = text.replace(link[0], ', ')    
    return text

def strip_all_entities(text):
    entity_prefixes = ['@','#']
    for separator in  string.punctuation:
        if separator not in entity_prefixes :
            text = text.replace(separator,' ')
    words = []
    for word in text.split():
        word = word.strip()
        if word:
            if word[0] not in entity_prefixes:
                words.append(word)
    return ' '.join(words)

# %%
def clean_str(s):
    """Clean sentence"""
    if type(s) is float:
        return s
    if len(s)<1:
        return s
    s = strip_all_entities(strip_links(s))
    s = re.sub(r"[^A-Zæåøa-z0-9#,\??\'\`]", " ", s)
    s = re.sub(r"\'s", " \'s", s)
    s = re.sub(r"\'ve", " \'ve", s)
    s = re.sub(r"n\'t", " n\'t", s)
    s = re.sub(r"\'re", " \'re", s)
    s = re.sub(r"\'d", " \'d", s)
    s = re.sub(r"\'ll", " \'ll", s)
    s = re.sub(r",", " , ", s)
    s = re.sub(r"!", " ! ", s)
    s = re.sub(r"\(", " \( ", s)
    s = re.sub(r"\)", " \) ", s)
    #s = re.sub(r"\?", " \? ", s)
    # s = nb_tokenizer(s)
    doc = nlp(s,disable=['parser', 'ner'])
    tokens = [tok.text.lower().strip() for tok in doc if tok.pos_ in  ['NOUN','PROPN','ADJ','ADV']]
    tokens = ' '.join(tokens)
    return tokens.strip().lower()

# %%
df['text_clean'] = df['text'].map(lambda x: clean_str(x))

# %% [markdown]
# Extract Local terms

# %%
def extract_hashtags(tweet):
    return set(re.findall(r"#(\w+)", tweet))

# %%
def filter_postags(tweet):
    tweet = clean_str(tweet)
    doc = nlp(tweet) 
    for tok in doc:
        print(tok.pos_, tok.text)

# %%
from sklearn.model_selection import train_test_split

# %%
x=df['text_clean']

# %%
y=df['state']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %% [markdown]
# Model benchmarking

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.linear_model import RidgeClassifier
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import NearestCentroid
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils.extmath import density
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import numpy as np

# %%
target_names = y.unique()

# %%
target_names
# Out:
# array(['California', 'Georgia', 'Maryland', 'Massachusetts', 'Minnesota',
#        'New York', 'Texas', 'Louisiana', 'North Carolina', 'New Jersey',
#        'Arizona', 'Florida', 'Oregon', 'Tennessee', 'Illinois', 'Ohio',
#        'Washington', 'Indiana', 'Nevada', 'Michigan', 'Utah',
#        'South Carolina', 'Missouri', 'Colorado', 'Pennsylvania',
#        'Connecticut', 'Wisconsin', 'Virginia', 'Oklahoma', 'Alabama',
#        'Iowa'], dtype=object)

# %%
feature_names = []

# %%
def vectorize(vect,X_train,X_test,chisquare=False,n_features=10000):
    if vect == "hashing":
        vectorizer = HashingVectorizer(stop_words='english', alternate_sign=False,
                                       n_features=2 ** 16)
        X_train = vectorizer.transform(X_train)
    else:
        vectorizer = TfidfVectorizer(sublinear_tf=True, max_df=0.5,
                                     stop_words='english')
        X_train = vectorizer.fit_transform(X_train)
    X_test = vectorizer.transform(X_test)
    if vect == "hashing" :
        feature_names = None
    else:
        feature_names = vectorizer.get_feature_names()
    if chisquare:
        ch2 = SelectKBest(chi2, k=n_features)
        X_train = ch2.fit_transform(X_train, y_train)
        X_test = ch2.transform(X_test)
        if feature_names:
            # keep selected feature names
            feature_names = [feature_names[i] for i
                             in ch2.get_support(indices=True)]
        print("selected features using chi2")
    if feature_names:
        feature_names = np.asarray(feature_names)
        return X_train,X_test,feature_names
    return X_train,X_test

# %%
def benchmark(clf,print_top10 = True,print_report = False):
    print("Training: ")
    print(clf)
    clf.fit(X_train, y_train)
    print("trained model")
    pred = clf.predict(X_test)
    print("predicted using model")

    score = metrics.accuracy_score(y_test, pred)
    print("accuracy:   %0.3f" % score)

    if hasattr(clf, 'coef_'):
        print("dimensionality: %d" % clf.coef_.shape[1])
        print("density: %f" % density(clf.coef_))

        if print_top10 and feature_names is not None:
            print("top 10 keywords per class:")
            for i, label in enumerate(target_names):
                top10 = np.argsort(clf.coef_[i])[-10:]
                print("%s: %s" % (label, " ".join(feature_names[top10])))
        print()

    if print_report:
        print("classification report:")
        print(metrics.classification_report(y_test, pred,
                                            target_names=target_names))
    clf_descr = str(clf).split('(')[0]
    return clf_descr, score

# %%
#noun, proper noun and adjective
X_train,X_test,feature_names = vectorize("tfidf",X_train,X_test,chisquare=True)
results = []
for clf, name in (
        (RidgeClassifier(tol=1e-2, solver="sag"), "Ridge Classifier"),
        (Perceptron(max_iter=100), "Perceptron"),
        (PassiveAggressiveClassifier(max_iter=100),
         "Passive-Aggressive"),
        (KNeighborsClassifier(n_neighbors=10), "kNN"),
        (LogisticRegression(n_jobs=1,C=1e5,max_iter=100),"lr"),
        (RandomForestClassifier(), "Random forest")):
    print('=' * 80)
    print(name)
    results.append(benchmark(clf))
# Out:
# selected features using chi2
# ================================================================================
# Ridge Classifier
# Training:
# RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#                 max_iter=None, normalize=False, random_state=None, solver='sag',
#                 tol=0.01)
# trained model
# predicted using model
# accuracy:   0.447
# dimensionality: 10000
# density: 0.999816
# top 10 keywords per class:
# California: juse asterisk eagle tuscaloosa birmingham bham bama huntsville auburn alabama
# Georgia: sedona asu tucson tempe suns arizona phoenix phx az scottsdale
# Maryland: xo angeles ca diego sd california hollywood san sf la
# Massachusetts: missrachel nuggets broncos ski rockies mlsdonkey snow boulder colorado denver
# Minnesota: sinergyst inactives fairfield norwalk espn2 indigodreamer reaction ct hartford stamford
# New York: dade jacksonville bios dolphins bucs fl miami tampa florida orlando
# Texas: buckhead hawks alpharetta shawty savannah georgia falcons ga atl atlanta
# Louisiana: daley wgn bulls il cta illinois twisten bears chi chicago
# North Carolina: triviathon qlixter dennie iu affluence mothpod colts hoosiers indy indiana
# New Jersey: taylorf ratenerd vps mol delluniversity kimble requester des moines iowa
# Arizona: rouge dat lyricsift geaux hydroponics lsu louisiana saints orleans nola
# Florida: skins brandweek godsound soundz lls ravens md maryland bmore baltimore
# Oregon: mbta sox bos worcester natick harvard ma massachusetts cambridge boston
# Tennessee: lions hex southfield lansing msu rapids arbor mi michigan detroit
# Illinois: vikings peterson vikes msp collegerecruiter rse minnesota minneapolis mpls mn
# Ohio: nscaa stl kdhx molina bruceandtrisha inventors mizzou tammyjo kc missouri
# Washington: voss nightclub ats strip reno lv nevada unlv las vegas
# Indiana: mya zenfuldance asbury wfmu newark hansen zukav hoboken jersey nj
# Nevada: syracuse smh rochester soho yankees knicks brooklyn york ny nyc
# Michigan: duke carolina carolinas clt chapel unc greensboro raleigh charlotte nc
# Utah: akron cincy dayton toledo osu bengals columbus cincinnati cleveland ohio
# South Carolina: norman cowgirl vavrinak osu stillwater genxnow green22 tulsa okc oklahoma
# Missouri: wellwire pug odesk eugene longbottomcoffee oregonian ducks oregon pdx portland
# Colorado: pgh burgh phillies scranton steelers septa pa philadelphia pittsburgh philly
# Pennsylvania: gamecocks myrtle cocks irmo medeitsch carolina charleston clemson greenville sc
# Connecticut: mznicole escalator pkg lawson jmwevh titans tennessee tn nashville memphis
# Wisconsin: dfw atx antonio tx texans cowboys texas austin houston dallas
# Virginia: provo ut snowmaker mlms gotrump salt responder utes slc utah
# Oklahoma: hoge redskins odu ayyjay rva pearla hokies virginia richmond va
# Alabama: uw spokane ballard tacoma bellevue huskies washington wa dc seattle
# Iowa: prevagen packers deuces mke uw wi badgers wisconsin madison milwaukee
#
# ================================================================================
# Perceptron
# Training:
# Perceptron(alpha=0.0001, class_weight=None, early_stopping=False, eta0=1.0,
#            fit_intercept=True, max_iter=100, n_iter_no_change=5, n_jobs=None,
#            penalty=None, random_state=0, shuffle=True, tol=0.001,
#            validation_fraction=0.1, verbose=0, warm_start=False)
# trained model
# predicted using model
# accuracy:   0.360
# dimensionality: 10000
# density: 0.189394
# top 10 keywords per class:
# California: birmingham bowmann jox eagle huntsville bham joxfm tre juse planetxbox360
# Georgia: writters gamere fvf scottsdale maibach koerber dboi ansi cnen asu
# Maryland: nobler la indexers rahim madone sf chargers usc roam spiller
# Massachusetts: goodbelly mlsdonkey inthe213 monkee favored lumi sxm zaibatsu sickboobs rhymesayers
# Minnesota: ct reservedmag sinergyst bridgeport stangl smoochy nagsandbrags lewn reaction indigodreamer
# New York: fausto dade broward drew32 tallahassee prudential miami belfort bucs tampa
# Texas: peachtree streetz almst a3c atlanta numer alpharetta prncess superfetch luckie
# Louisiana: volterra blackhawks everyweek halsted wgn adair giordano wbbm chgo chicago
# North Carolina: indiana vodpod bernicole triviathon lifework pintura dennie affluence qlixter mothpod
# New Jersey: fyne dlf soltanian sakebombs des ratenerd moines requester bhb taylorf
# Arizona: saints whodat nola metairie kango origamiwarrior lyricsift lsu bg upi
# Florida: guffly supercaps reisterstown soundz obx lighthouses maryland pnreapentertainment burgaw ohso
# Oregon: yro daaance emailsfrommymother natick puerco bedbugbytes wccc artgibson tacworldwide blizz
# Tennessee: fatale357 nyc0le bullfrog lifewater ingy 0rgasm piston thegr8 fathead 55p
# Illinois: iont localtweeps icumarketing tmicbeats lussier mpls phun fabulus livescience collegerecruiter
# Ohio: tiwtter twitlistbgary jcdmchurchbuilders nscaa molina kdhx jcof bruceandtrisha vtpk missouri
# Washington: zumanity nlv lavo biitch xoca loko docluv ats sj39 walther
# Indiana: hoboken cormega drooyoographix hellhoundstudios arsonal llenergy cornelwest budden zenfuldance shailene
# Nevada: leveling knicks dickies rochester reportlinker nyc policymakers mindmap syracuse msp
# Michigan: emikoooooooooooo thirdfresh dizzle saucedup megachurch hoho deadskins fixtures bizzopcom northlake
# Utah: grunenwald binkymarie dbd amda cleveland fcukin ohio twitfreaks perfact woxy
# South Carolina: wayman kolke kenig tulsey rnbe edmond rapidrain green22 oklahoma genxnow
# Missouri: cassow clusty pdx webtrends bmighty illababy sqip visualizer textron longbottomcoffee
# Colorado: criss jiujitsumatrix septa geno burgh renter bpt gogohub hbg creasixteen
# Pennsylvania: repoed achiever chillian tangeria favored irmo greenville medeitsch kontent whyyyyyy
# Connecticut: ampro tennessee funshopmemphis musicmonday mznicole hvacreducation mtsu more4kids jmwevh memphis
# Wisconsin: plano vdara atx moines greenhouses dfw suitcases peddler htown spurs
# Virginia: utah upi bootstrapbusiness nethosting campusbookrentals slc mxm nextfit responder gotrump
# Oklahoma: exxtra odu va chavisthejeweler richmond hartz moradas shiest benwell mwatts
# Alabama: seattle arenas felted entertonement bellevue sounders dispatcher franchize livemocha dc
# Iowa: sushilor birdwatching azrou rodgers swindle milwaukee rawrock badgers terrrific prevagen
#
# ================================================================================
# Passive-Aggressive
# Training:
# PassiveAggressiveClassifier(C=1.0, average=False, class_weight=None,
#                             early_stopping=False, fit_intercept=True,
#                             loss='hinge', max_iter=100, n_iter_no_change=5,
#                             n_jobs=None, random_state=None, shuffle=True,
#                             tol=0.001, validation_fraction=0.1, verbose=0,
#                             warm_start=False)
# trained model
# predicted using model
# accuracy:   0.456
# dimensionality: 10000
# density: 0.307703
# top 10 keywords per class:
# California: tuscaloosa springhill saban kellun tre juse huntsville moneycoach101 bowmann bham
# Georgia: abet sedona trendfinder kupd dboi tempe tucson asu phx scottsdale
# Maryland: ca california usc sd hollywood chargers san angeles sf la
# Massachusetts: starstrukk missrachel zaibatsu kyaizen rockies mlsdonkey avs boulder colorado denver
# Minnesota: norwalk stamford grabow indigodreamer hartford sinergyst midseason postively hamel danbury
# New York: lauderdale bios miami sarasota bucs dade florida broward orlando tampa
# Texas: primal buckhead luckie kasim savannah ga alpharetta falcons atl atlanta
# Louisiana: bears lep chicagoland illinois halsted chi wgn twisten cta chicago
# North Carolina: kaigler kiddinaroundusa triviathon esbjournal nincha wbgl mothpod urbanusaonline business901 affluence
# New Jersey: defectors sakebombs auctioneers des ladygoodman iowa ratenerd kimble requester moines
# Arizona: bloodroot revan dukky metroid saints upi lsu nola hydroponics lyricsift
# Florida: yazurlo bails86 richgirl soundz brandweek nagga smith01 godsound baltimore bmore
# Oregon: artgibson faulk waltham pingo worcester cambridge bos boston mbta natick
# Tennessee: ohs lansing blackmagic msu rapids hex artprize michigan southfield detroit
# Illinois: minnesota copycatsmedia touchstone magers lasserre mn localtweeps rse collegerecruiter mpls
# Ohio: mabel rvers nscaa adherence mizzou bruceandtrisha directpi molina jcdmchurchbuilders tammyjo
# Washington: citycenter colosseum darvan cfb reno braveheart ats tomstvshow lavo unlv
# Indiana: maxwells asbury twrs fripp jumpsnap nwk zukav fahbhlaqq nypoleon firebaugh
# Nevada: dahl york upstate syracuse ny nyc rochester knicks soho brooklyn
# Michigan: natstar fixtures nc rdu carolinas charlotte xtremepicks greensboro raleigh clt
# Utah: sportsims pinhole flaubert bizsugar toledo bengals dillio cleveland osu ohio
# South Carolina: runningguru ecorazzi rapidrain edmond unofficialapple tulsa genxnow okc green22 oklahoma
# Missouri: visualizer sqip iweb lauraveirs blogomator oregonian wellwire oregon portland pdx
# Colorado: hbg patten pittsburgh philly arghh shadyside pgh scranton burgh septa
# Pennsylvania: gamecocks golfmasters horry manhunters nicekicks lagos greenville clemson irmo medeitsch
# Connecticut: relache rocketown neopolitan tennessee plummer ryman ravenhill jmwevh mznicole memphis
# Wisconsin: htown texas dfw heb atx peddler texans austin dallas houston
# Virginia: rsl ut mormon responder nethosting bootstrapbusiness utes slc gotrump utah
# Oklahoma: phe ayyjay benwell rva richmond perriello shelle hoge pearla hokies
# Alabama: seatac wa tacoma ballard spokane entertonement dc huskies bellevue seattle
# Iowa: madison rodgers mke neenah whatthefuck wisconsin clep grandperfumes milwaukee badgers
#
# ================================================================================
# kNN
# Training:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')
# trained model
# predicted using model
# accuracy:   0.346
# ================================================================================
# lr
# Training:
# LogisticRegression(C=100000.0, class_weight=None, dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='warn', n_jobs=1, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)
# /Users/divyanshumarwah/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/divyanshumarwah/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# trained model
# predicted using model
# accuracy:   0.350
# dimensionality: 10000
# density: 1.000000
# top 10 keywords per class:
# California: midsize eagle chapel klutz birmingham generically dewy workbay damons planetxbox360
# Georgia: horry fvf wacked ev1 barbosa ansi kiawah yazoo photograp wey
# Maryland: firsttake bagdad moreira roam 4v cassius timepieces ypsilanti broomfield shanell
# Massachusetts: favored mankato renegades inthe213 orangeburg nfc charle rhymesayers grigsby clarksville
# Minnesota: pardcast sdc stamford ct reaction smoochy hartford bram 4x postively
# New York: griese eatn mazzella prudential kgw khartoum burnie papago conneticut heav
# Texas: achive westbank okla kasim grigsby numer hennepin latrine fms dundalk
# Louisiana: wbbm ecorazzi zins grizzley berrian wgn sano babycenter commanders maddy
# North Carolina: umake lampert telephony jvk consulates bolan pintura lifework macgyver abbreviated
# New Jersey: rattray kinoki mechanically mclean des ladygoodman avw kimble moines iowa
# Arizona: grisham hydroponics socme lyricsift dukky revan saints upi nola origamiwarrior
# Florida: thrones smedes burgaw isu prs stakeholder obx archibald ohso silvana
# Oregon: smr varitek daley junkfood sandusky blizz tacworldwide eyepatch clermont audiation
# Tennessee: osan osprey green22 flacco fms heiser lifewater athelete grizzlies 55p
# Illinois: socialnomics minnesota bis icumarketing stamford collegerecruiter crazymotion mwf agriprocessors photographyblog
# Ohio: preposition peoplestring midwest kc twtpoll mizzou missouri rji molina boorstin
# Washington: adia presumptuous ats loko resturant unlv varitek kelliher kasper trin
# Indiana: cornelwest kenig jersey erian cormega phils shailene laseter coyotes photographyblog
# Nevada: mediacom gamecock slumberland ls9 jayhawk policymakers bryon koppen mabel legarrette
# Michigan: adherence northlake orem gamecocks beadle deadskins carolinas kiffin sweidan vess
# Utah: kiffin lacerations superfood perfact babi feherty crossmark k2 tivation shortstop
# South Carolina: green22 arleen mcb cinnie wx1 okc contingency oklahoma globalism semblance
# Missouri: cassow lovies pdx gaertner visualizer lco nfc biodiesel javers nikesoccer
# Colorado: durant espnu af1 mcgill spasm shadyside salgado jampolsky karza hbg
# Pennsylvania: griessman atlanticville photocopies bruhh jacksonville greenville metairie globe favored whyyyyyy
# Connecticut: straite junquee ecpa designologue scrollbar jimbo more4kids ravenhill scrollbars memphis
# Wisconsin: corned childress stocked 12k cystic marmaduke ostomy marquette downt staggerin
# Virginia: podria upi dealzmodo multiroom fairhope codigo slc utah cabinetry responder
# Oklahoma: benwell eatn rva punky baton kalyn maryjane starkville twidiot stillwater
# Alabama: g2e minnpost firebaugh arghhhhhhh aq buoys defector franchize sumter wyff
# Iowa: tyque postpaid oklahoma swindle badgers terrrific promega rawrock iowans mbta
#
# ================================================================================
# Random forest
# Training:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators='warn',
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# /Users/divyanshumarwah/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# trained model
# predicted using model
# accuracy:   0.369

# %%
#noun, proper noun and adjective
X_train,X_test = vectorize("hashing",X_train,X_test,chisquare=True)
results = []
for clf, name in (
        (RidgeClassifier(tol=1e-2, solver="sag"), "Ridge Classifier"),
        (Perceptron(max_iter=100), "Perceptron"),
        (PassiveAggressiveClassifier(max_iter=100),
         "Passive-Aggressive"),
        (KNeighborsClassifier(n_neighbors=10), "kNN"),
        (LogisticRegression(n_jobs=1,C=1e5,max_iter=100),"lr"),
        (RandomForestClassifier(), "Random forest")):
    print('=' * 80)
    print(name)
    results.append(benchmark(clf))
# Out:
# selected features using chi2
# ================================================================================
# Ridge Classifier
# Training:
# RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#                 max_iter=None, normalize=False, random_state=None, solver='sag',
#                 tol=0.01)
# trained model
# predicted using model
# accuracy:   0.406
# dimensionality: 10000
# density: 0.999997
# top 10 keywords per class:
# California: imitates mobiletwitter unsexy tipps wilhite cmnhospitals wyff interestin mbta thaaaaaaaa
# Georgia: omniweb maxam thiopental tinora geeeny alexander81 relays homless 6n ner
# Maryland: facebooktips4u rashford earnhardt medicating geekz huffingtonpost mwahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahaha 50f fuglies badgers
# Massachusetts: ridiciulous approachin irresistibly ks360 hartford prov1s faaashhooo iamsuperexcitedfortonightthepartyisgonnabesomuchfun guitarworld gonzalez
# Minnesota: zander liesel mamola collinearl doctorlady paymah dagg sumfin swett cbwebdesigner
# New York: minneapolis 4got toolset plummer wholesalers conchal cadd oooooohhh dreamsz corvair
# Texas: uym tracter boston dresserafterdark mattie cuccinelli olmenius burgh bartlet fripp
# Louisiana: dillio burdons agadeem deliverable rtwrestlingradio emocionou eventhash merrie inclu loseweighttweet
# North Carolina: staright copyeditor himmmmmmmm fooley carlosbakery sniffable ster chieftains mylilrobotponies dewd
# New Jersey: trapn tweetsurge panis corvallis prole coochieness imagenary drcornelwest rossjoyner minez
# Arizona: physikalisch angeles sucheth latteland trautwen abc3340 direpectful lovesome chicago bluh
# Florida: shockhound youngjaxso cinnie trebuchet rlp curli2007 maddy harperstudio raat ohs
# Oregon: dealmoon thefamily curys jennandrob leviathin gridsnoots recurrent cookn goooooogle tacoma
# Tennessee: amenable byway steckel tellement insell xtremeterrainjeepparts kideight cammy hvywgt thingsthatmakescents
# Illinois: ricoeur twask barna responder rokia msbuild rickafox chito slashed ts15
# Ohio: bbh ut semblance ancona dissolves unforgiveable tybee ypsilanti luckie trinxxxer
# Washington: hickman birchfield udid crossmovement sbf ridinger jobcircle madone rho nwe
# Indiana: grice gaypublic oddparents scumbagstyle wxbt digitalfest babygirls fringeromp hoovers keybordcat
# Nevada: apostasy long1 agita ruxbein pjohnso reconstructive more4kids lampi bigtymers 567th
# Michigan: harbison 918moms fogel pontiac zenful coachmatthewjohnson d3stiny kerkyra dickblick worrd
# Utah: soner powerratings deveney waaaaaaaay letsshare johor flq mangos thepeopleofwalmart bizzopcom
# South Carolina: refiller torley yrself unanymous adobe10off helllll biletnikoff friendsfriday smebody tagab
# Missouri: mojiva minix duke hooten banjar watchinglast rwe ebahama cssperk polskie
# Colorado: extenz microenterprise comedown barmitzvah wakelin 562nd uuugggghh kolln parise taylrmayd
# Pennsylvania: brraaap hailarous matt16 uppsala alegent ckers iannelli szvetitz growstillwater theobromine
# Connecticut: tedy dessa jednipple wilkesboro ssw milkmen kanteen handerpants bavu brammo
# Wisconsin: thiiiis kamigawa mccorkle crafton creationism jgdpmpj unbareable gordini lv gingivitis
# Virginia: gaier hideaway helton megaregion callingallvets corns wnw salario firebaugh sd
# Oklahoma: kidsmeal pales nimzito zzzzzzzzzzzzzzzzzzz ecoshield notcot dollie karowoski streetkingz coralville
# Alabama: amoroso petrone getttttt fidler kspi wantabe enduracare dleay hbg platypi
# Iowa: substati paca twnhm elimi fireeee crozier pawlenty ladyfriends micahi stephenwolfesstuff
#
# ================================================================================
# Perceptron
# Training:
# Perceptron(alpha=0.0001, class_weight=None, early_stopping=False, eta0=1.0,
#            fit_intercept=True, max_iter=100, n_iter_no_change=5, n_jobs=None,
#            penalty=None, random_state=0, shuffle=True, tol=0.001,
#            validation_fraction=0.1, verbose=0, warm_start=False)
# trained model
# predicted using model
# accuracy:   0.329
# dimensionality: 10000
# density: 0.636719
# top 10 keywords per class:
# California: mbta tipps procrastinators venema randallstown dannnggg cmnhospitals wyff unsexy thaaaaaaaa
# Georgia: hoovers thiopental maxam tinora alexander81 geeeny relays 6n ner homless
# Maryland: dilworth playdar chellie rltw huffingtonpost thechristianauthorsshow rtkatyinindy herbstriet rashford badgers
# Massachusetts: bsd ks360 scdp angelictouchdesigns pizzabarfor 550am iamsuperexcitedfortonightthepartyisgonnabesomuchfun faaashhooo guitarworld gonzalez
# Minnesota: rallyamericaseries saabsquad beady ruinsinred dagg yancy swett paymah cbwebdesigner damone
# New York: wdw conchal plummer tofollow minneapolis ariston cadd oooooohhh corvair dreamsz
# Texas: dboi synthtopia boston mvsb skiddish olmenius mattie burgh fripp bartlet
# Louisiana: seneng grisham kavemayne eventhash reactivity hierarch 4show emocionou inclu loseweighttweet
# North Carolina: copyeditor incendonet thefabgiver thechunkycoed pyp malicki rpgenie mylilrobotponies vppig dewd
# New Jersey: az prole repetido swooping imagenary rangerr drcornelwest rossjoyner kwss minez
# Arizona: gont gsl latteland howrd commandite direpectful abc3340 bluh chicago lovesome
# Florida: 199lease danan artistics skoooool rlp maddy curli2007 raat harperstudio ohs
# Oregon: twecklers grandover swooping cookn mtsu themodernelite thefamily feinsteins muxtape tacoma
# Tennessee: nypoleon xtremeterrainjeepparts healthbeat fightclub insell cammy tellement fowllowers hvywgt thingsthatmakescents
# Illinois: someoneeeeeee awwwwwwwwwwwww cinderkeys goaggies rickafox ricoeur slashed msbuild chito ts15
# Ohio: semblance truediamond streetzz unforgiveable ypsilanti luckie ut trinxxxer bbh tybee
# Washington: benater rho appleton mcb ridinger crossmovement hickman madone cornette nwe
# Indiana: matias fringeromp cassies camoflauge pasandola indent artfire dennie keybordcat hoovers
# Nevada: odesk bigtymers crookston djaycas pnemonia more4kids theattentionconnection forgiver 567th pjohnso
# Michigan: yatagarasu prelim edumacation nooshi harbison coachmatthewjohnson d3stiny kerkyra dickblick worrd
# Utah: deveney letsshare rooolz nacy johor powerratings flq thepeopleofwalmart mangos bizzopcom
# South Carolina: radiothon wwfm youngexplorers awana tigard adobe10off biletnikoff friendsfriday smebody tagab
# Missouri: wallie powerplant backgorund minix langosta duke hooten watchinglast cssperk polskie
# Colorado: keytar omniforex celi transportability wihout wakelin kolln uuugggghh taylrmayd parise
# Pennsylvania: redlights hailarous regretfully amcom alegent szvetitz ckers iannelli growstillwater theobromine
# Connecticut: dessa amcom strngs tvv kanteen ssw handerpants wickednemesis bavu brammo
# Wisconsin: odu edutainment unbareable twitterd thiiiis kamigawa jgdpmpj lv gingivitis gordini
# Virginia: feg pressler iamsuperexcitedfortonightthepartyisgonnabesomuchfun corns iberville bluemarble4lifeblog crofoot megaregion salario sd
# Oklahoma: bucs huffing milwaukee ponderous unconfined humourously tothink karowoski streetkingz coralville
# Alabama: repaying sybil petroff buiseness erian cinnie kspi dleay hbg platypi
# Iowa: swarbrick paca elimi kbc cafos ladyfriends pawlenty micahi twnhm stephenwolfesstuff
#
# ================================================================================
# Passive-Aggressive
# Training:
# PassiveAggressiveClassifier(C=1.0, average=False, class_weight=None,
#                             early_stopping=False, fit_intercept=True,
#                             loss='hinge', max_iter=100, n_iter_no_change=5,
#                             n_jobs=None, random_state=None, shuffle=True,
#                             tol=0.001, validation_fraction=0.1, verbose=0,
#                             warm_start=False)
# trained model
# predicted using model
# accuracy:   0.364
# dimensionality: 10000
# density: 0.877290
# top 10 keywords per class:
# California: procrastinators wyff randallstown mbta priorties cmnhospitals mobiletwitter dannnggg unsexy thaaaaaaaa
# Georgia: welcom tinora thiopental maxam geeeny alexander81 ner 6n homless relays
# Maryland: horry vezner playdar jacksonville dilworth chellie thechristianauthorsshow herbstriet rashford badgers
# Massachusetts: projectlabel havnevik 550am luce bsd pizzabarfor iamsuperexcitedfortonightthepartyisgonnabesomuchfun faaashhooo guitarworld gonzalez
# Minnesota: quanna yancy krate lilwil saabsquad damone swett dagg paymah cbwebdesigner
# New York: conchal wdw plummer tofollow ariston cadd minneapolis oooooohhh corvair dreamsz
# Texas: frweezing boston colledge diigo mvsb olmenius burgh mattie fripp bartlet
# Louisiana: shatnerquake eventhash cqs hierarch kavemayne grisham 4show reactivity inclu loseweighttweet
# North Carolina: vppig fooley mylilrobotponies ster driod copyeditor pyp carlosbakery rpgenie dewd
# New Jersey: underpasses coochieness swooping kwss prole imagenary panis drcornelwest rossjoyner minez
# Arizona: workingtons urbanthoreau gont latteland howrd abc3340 direpectful bluh chicago lovesome
# Florida: bottletree danan rlp trebuchet skoooool raat harperstudio curli2007 maddy ohs
# Oregon: themodernelite bocconcini grandover thefamily lifestages xuxkj markausmusic feinsteins muxtape tacoma
# Tennessee: xtremeterrainjeepparts paddles healthbeat nypoleon tellement insell fightclub fowllowers hvywgt thingsthatmakescents
# Illinois: cinderkeys spottsville rickafox project3090 someoneeeeeee ricoeur msbuild slashed chito ts15
# Ohio: ancona pastorelli youronramp ut bbh ypsilanti truediamond luckie trinxxxer tybee
# Washington: affillate lmbaooooooooooo cimmicsymsofficial goldhar hickman rho crossmovement cornette madone nwe
# Indiana: artfire genesis fringeromp digitalfest camoflauge indent scumbagstyle dennie keybordcat hoovers
# Nevada: bigtymers apparentky pnemonia 567th theattentionconnection djaycas more4kids crookston forgiver pjohnso
# Michigan: pontiac prelim yatagarasu edumacation montgomery d3stiny coachmatthewjohnson kerkyra dickblick worrd
# Utah: nacy luuuuuuvvvv letsshare whodatapp powerratings johor thepeopleofwalmart flq mangos bizzopcom
# South Carolina: unanymous tigard helllll wwfm youngexplorers adobe10off friendsfriday biletnikoff smebody tagab
# Missouri: eeeeeeeeee asdlfkj contradictlexia mwwt duke hooten minix watchinglast polskie cssperk
# Colorado: barmitzvah transportability wihout 562nd celi wakelin kolln uuugggghh taylrmayd parise
# Pennsylvania: regretfully brraaap matt16 groaner alegent ckers iannelli szvetitz growstillwater theobromine
# Connecticut: amcom dessa merello ooookaaaayyy handerpants tvv kanteen ssw bavu brammo
# Wisconsin: unharmed odu unbareable twitterd thiiiis kamigawa jgdpmpj lv gingivitis gordini
# Virginia: figh offshoreonly iberville fazoli callingallvets megaregion corns salario wnw sd
# Oklahoma: scrollbar iowa humourously huffing sebold milwaukee tothink karowoski streetkingz coralville
# Alabama: cinnie onetravel sfz petroff agco buiseness kspi dleay hbg platypi
# Iowa: paca ladyfriends uwcea cafos kbc pawlenty elimi twnhm micahi stephenwolfesstuff
#
# ================================================================================
# kNN
# Training:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')
# trained model
# predicted using model
# accuracy:   0.214
# ================================================================================
# lr
# Training:
# LogisticRegression(C=100000.0, class_weight=None, dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='warn', n_jobs=1, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)
# /Users/divyanshumarwah/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/divyanshumarwah/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/divyanshumarwah/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/divyanshumarwah/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# trained model
# predicted using model
# accuracy:   0.352
# dimensionality: 10000
# density: 1.000000
# top 10 keywords per class:
# California: berz randallstown mbta dannnggg priorties mobiletwitter bombard cmnhospitals unsexy thaaaaaaaa
# Georgia: welcom t2a tinora kevinnottingham geeeny alexander81 ner relays homless 6n
# Maryland: chellie rltw vezner trott thechristianauthorsshow malawa herbstriet rashford dilworth badgers
# Massachusetts: luce traverus goodmooorrnnniiinnggg pizzabarfor jacksonorleans1 iamsuperexcitedfortonightthepartyisgonnabesomuchfun wisconisn faaashhooo guitarworld gonzalez
# Minnesota: lilwil saabsquad thetandd damone swett paymah ruinsinred beady dagg cbwebdesigner
# New York: gambrills plummer willaim tofollow minneapolis ariston cadd oooooohhh corvair dreamsz
# Texas: uummm fcukin fuma meganne diigo olmenius burgh mattie fripp bartlet
# Louisiana: frou hierarch groepschoreografie kavemayne shatnerquake 4show vestival grisham reactivity loseweighttweet
# North Carolina: mylilrobotponies ster wntn driod pyp copyeditor rpgenie carlosbakery thefabgiver dewd
# New Jersey: panis davecrenshaw kwss prole imagenary underpasses drcornelwest rossjoyner chippendales minez
# Arizona: latteland abc3340 gsl direpectful gont howrd henning bluh chicago lovesome
# Florida: radikal trebuchet rlp danan raat skoooool harperstudio maddy curli2007 ohs
# Oregon: pitfall lifestages thefamily grandover kute feinsteins paynus muxtape bocconcini tacoma
# Tennessee: ravenhill nypoleon paddles insell jalaynna nashvile fightclub fowllowers hvywgt thingsthatmakescents
# Illinois: cinderkeys goaggies awwwwwwwwwwwww fahso someoneeeeeee ricoeur msbuild slashed chito ts15
# Ohio: tial lol pastorelli bbh doprah ypsilanti luckie trinxxxer truediamond tybee
# Washington: olmstead rho hickman goldhar ridickulus crossmovement madone minja cornette nwe
# Indiana: apg scumbagstyle fringeromp camoflauge dennie cassies roeg keybordcat matias hoovers
# Nevada: djaycas 567th pnemonia more4kids ashaan apparentky forgiver diversifies pjohnso bergilir
# Michigan: acrylate yatagarasu montgomery lonczak edumacation d3stiny coachmatthewjohnson kerkyra dickblick worrd
# Utah: rooolz eunejeune diversifies luuuuuuvvvv powerratings johor thepeopleofwalmart flq mangos bizzopcom
# South Carolina: shults helllll youngexplorers communisim theborgata adobe10off friendsfriday biletnikoff smebody tagab
# Missouri: mwwt asdlfkj contradictlexia vbr wallie hooten minix watchinglast polskie cssperk
# Colorado: sweetburns mik bowes 562nd celi wakelin kolln uuugggghh taylrmayd parise
# Pennsylvania: brraaap seurat alegent groaner matt16 iannelli ckers szvetitz growstillwater theobromine
# Connecticut: nssn handerpants richmond hornbill tvv heartsongs ssw kanteen bavu brammo
# Wisconsin: opencongress keytar twitterd thiiiis kamigawa jgdpmpj sexaholic gingivitis lv gordini
# Virginia: sowwwy bluemarble4lifeblog salario megaregion fazoli corns cummz wnw sensl sd
# Oklahoma: humourously milwaukee ponderous sebold tothink scrollbar huffing karowoski streetkingz coralville
# Alabama: mazzella onetravel agco kspi petroff convection sfz dleay hbg platypi
# Iowa: ladyfriends elimi uwcea drogen fcukin pawlenty conpany twnhm micahi stephenwolfesstuff
#
# ================================================================================
# Random forest
# Training:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators='warn',
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# trained model
# predicted using model
# accuracy:   0.312

# %%
#noun and proper noun
X_train,X_test,feature_names = vectorize("tfidf",X_train,X_test,chisquare=True)
results = []
for clf, name in (
        (RidgeClassifier(tol=1e-2, solver="sag"), "Ridge Classifier"),
        (Perceptron(max_iter=100), "Perceptron"),
        (PassiveAggressiveClassifier(max_iter=100),
         "Passive-Aggressive"),
        (KNeighborsClassifier(n_neighbors=10), "kNN"),
        (LogisticRegression(n_jobs=1,C=1e5,max_iter=100),"lr"),
        (RandomForestClassifier(), "Random forest")):
    print('=' * 80)
    print(name)
    results.append(benchmark(clf))
# Out:
# selected features using chi2
# ================================================================================
# Ridge Classifier
# Training:
# RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#         max_iter=None, normalize=False, random_state=None, solver='sag',
#         tol=0.01)
# trained model
# predicted using model
# accuracy:   0.447
# dimensionality: 10000
# density: 0.999900
# top 10 keywords per class:
# California: juse asterisk eagle tuscaloosa birmingham bham auburn bama huntsville alabama
# Georgia: modexperts asu suns tucson tempe phoenix arizona phx az scottsdale
# Maryland: angeles los diego ca sd california hollywood san sf la
# Massachusetts: missrachel broncos nuggets ski rockies snow mlsdonkey boulder colorado denver
# Minnesota: nagsandbrags inactives fortifiedrecords fairfield norwalk indigodreamer reaction ct hartford stamford
# New York: dolphins lauderdale ucf bios bucs fl miami tampa florida orlando
# Texas: hawks alpharetta shawty preciate savannah georgia falcons ga atl atlanta
# Louisiana: bayless wgn bulls illinois cta il twisten bears chi chicago
# North Carolina: triviathon iu qlixter dennie affluence mothpod colts hoosiers indy indiana
# New Jersey: mclean ratenerd delluniversity requester mol kimble webhosting des moines iowa
# Arizona: upi kango lyricsift geaux hydroponics lsu louisiana nola saints orleans
# Florida: skins brandweek soundz godsound lls md ravens maryland bmore baltimore
# Oregon: sox lowell mbta bos harvard natick massachusetts ma cambridge boston
# Tennessee: southfield lions hex msu mi rapids arbor lansing michigan detroit
# Illinois: vikings peterson vikes msp collegerecruiter rse minnesota minneapolis mpls mn
# Ohio: kdhx bruceandtrisha stl teeing inventors molina mizzou tammyjo kc missouri
# Washington: casino nightclub strip ats lv reno nevada unlv las vegas
# Indiana: wen zenfuldance eternal wfmu saddling newark zukav hoboken jersey nj
# Nevada: smh jets soho rochester yankees knicks brooklyn york ny nyc
# Michigan: canes carolina carolinas clt chapel greensboro unc raleigh charlotte nc
# Utah: toledo cincy akron dayton osu bengals columbus cincinnati cleveland ohio
# South Carolina: rapidrain osu norman cowgirl stillwater genxnow green22 tulsa okc oklahoma
# Missouri: sqip wellwire pug odesk eugene longbottomcoffee ducks oregon portland pdx
# Colorado: burgh phila phillies steelers scranton septa philly pa philadelphia pittsburgh
# Pennsylvania: gamecocks myrtle cocks irmo medeitsch carolina charleston clemson greenville sc
# Connecticut: escalator mznicole lawson bejeweled jmwevh titans tennessee tn nashville memphis
# Wisconsin: dfw atx antonio cowboys tx texans texas austin houston dallas
# Virginia: ut objective provo snowmaker salt utes gotrump responder slc utah
# Oklahoma: kaine odu redskins ayyjay rva hokies pearla virginia richmond va
# Alabama: uw spokane ballard tacoma bellevue huskies washington wa dc seattle
# Iowa: prevagen packers deuces mke wi uw badgers wisconsin madison milwaukee
#
# ================================================================================
# Perceptron
# Training:
# Perceptron(alpha=0.0001, class_weight=None, eta0=1.0, fit_intercept=True,
#       max_iter=100, n_iter=None, n_jobs=1, penalty=None, random_state=0,
#       shuffle=True, tol=None, verbose=0, warm_start=False)
# trained model
# predicted using model
# accuracy:   0.338
# dimensionality: 10000
# density: 0.282645
# top 10 keywords per class:
# California: tre listverse alabama dewy huntsville bowmann bham joxfm planetxbox360 juse
# Georgia: dstv horry charlaine montery asu barbosa tutera comical photograp toor
# Maryland: toasted poisons gourmand preamp klean sizzle dreamlife belies timepieces broomfield
# Massachusetts: animate matey gj orangeburg nfc afc rhymesayers hamel grigsby clarksville
# Minnesota: fms twitjail reservedmag lewn reaction midseason fortifiedrecords espn2 nagsandbrags indigodreamer
# New York: dgb morristown crean khartoum peoplebrowsr tailspin prudential bls conneticut heav
# Texas: almst latrine numer ams westbank hennepin dundalk grigsby charchian bartlet
# Louisiana: stafford babycenter reccs zins wgn plaskett wbbm sano berrian commanders
# North Carolina: urbanusaonline tweetlarge dennie lifework macgyver qlixter mothpod mlmr lampert ecotourism
# New Jersey: ratenerd babylegs medieval kimble webhosting bhb requester taylorf iowa moines
# Arizona: geaux coer rothwell whodat saints gislason nola kango lsu lyricsift
# Florida: kikky richgirl unc odenton reairings pnreapentertainment ohso obx colussy silvana
# Oregon: puerco everyscape shortstop bedbugbytes teeing faulk daaance deleo smr tacworldwide
# Tennessee: eazy lifewater osan fathead fms heiser therosereport 55p typically athelete
# Illinois: buoys rse fabulus harried alarmists photographyblog phun icumarketing mwf collegerecruiter
# Ohio: molina jcdmchurchbuilders nscaa bruceandtrisha kc kdhx midwest jcof vtpk missouri
# Washington: nlv djlabels imu mirroball walther varitek adia kelliher unlv kasper
# Indiana: laseter dubais cornelwest twitcation zenfuldance suncera twitfam cormega photographyblog freeagent
# Nevada: gundy leav friendss whoeva controvery stacksss mabel starkville koppen legarrette
# Michigan: orem beadle slanted paperclip northlake carolinas deadskins kiffin megachurch sweidan
# Utah: perfact feherty skunks woxy kiffin tivation shortstop crossmark k2 awhhhh
# South Carolina: reactiongrid tulsa keselowski kawnar shakthi paulcounts okc oklahoma rapidrain genxnow
# Missouri: illababy exploding abductions mlsp webtrends pdx bmighty oden pottstown textron
# Colorado: bensen salgado wthr lowertown phenomenom somebodies jann karza shockey bpt
# Pennsylvania: disciple manhunters missniyha repoed tangeria rangerr kontent fuddy medeitsch successfull
# Connecticut: clarksville barfield bayne profiler jimbo hvacreducation mznicole mtsu memphis jmwevh
# Wisconsin: wget cystic fooley childress kivi staggerin franch waverly indiebizchicks ostomy
# Virginia: genealogical timeclick cabinetry pbskids nethosting bootstrapbusiness campusbookrentals gotrump nextfit maakoa
# Oklahoma: rva jank maryjane stillwater aamu misfortunes nco punky twidiot newswise
# Alabama: swolen dispatcher okayyy defector wyff northeastern arghhhhhhh grandmama sumter franchize
# Iowa: whatthefuck postpaid badgers spitz delon chesterfrench prevagen mbta rawrock startrek
#
# ================================================================================
# Passive-Aggressive
# Training:
# PassiveAggressiveClassifier(C=1.0, average=False, class_weight=None,
#               fit_intercept=True, loss='hinge', max_iter=100, n_iter=None,
#               n_jobs=1, random_state=None, shuffle=True, tol=None,
#               verbose=0, warm_start=False)
# trained model
# predicted using model
# accuracy:   0.418
# dimensionality: 10000
# density: 0.354642
# top 10 keywords per class:
# California: unconventional samford aerobie gosocial towleroad lifestages deschember berelevant dewy planetxbox360
# Georgia: barbosa kupd arrrgh phx kbs amadeus dstv samiam asu charlaine
# Maryland: sd spiller molson meaghan hollywood chargers san usc sf la
# Massachusetts: efiling scampi reefer pachelbel matey illustrative loveland zaibatsu denver attitiude
# Minnesota: hartford pardcast uigea rocketwave1 danbury quiona thnksgng mindful 4x twitjail
# New York: miami prudential jacksonville belfort florida bucs sarasota broward tampa orlando
# Texas: bsd falcons partna atl kasim uga luckie peachtree atlanta alpharetta
# Louisiana: argo cta wgn adair metrodome lawgang chgo chicagoland volterra chicago
# North Carolina: umake mlmr renegades yaaaaaaawn lampert lifework urbanusaonline tweetlarge essett ecotourism
# New Jersey: subdomain cinderkeys changeable sarathan liqwda defectors ratenerd avw kimble moines
# Arizona: coer rothwell twd20 breesus iheartnola elvy upi chimichungas lawwwd origamiwarrior
# Florida: luau parolees ohso burgaw kikky pearlier obx sabbatini stubbornness crds
# Oregon: studentbrandingblog tacworldwide eurovision boston baydin orgo bos alums popovers natick
# Tennessee: bullfrog nzb detroit twakeover southfield lifewater biggs fricken 55p whq
# Illinois: lussier autobiographies phun collegerecruiter tweetmymoney bagarius ezek fabulus icumarketing livescience
# Ohio: rvers richardbonilla traverus twtpoll preposition mizzou meformer kievman rji rayovak
# Washington: unlv dailystrength nlv twitpict walther colosseum pahrump lavo loko djlabels
# Indiana: grapeade dr3wz ganksta shailene illistrator suncera twitcation cormega laseter dubais
# Nevada: ny trott rochester dahl knicks boilers nyc upstate soho brooklyn
# Michigan: rdu dabeats slanted xtremepicks tunak sonogram fixtures caswell kthanks northlake
# Utah: aquinas 12flat isildur1 twan crazytee flaubert stuido colorin perfact cbus
# South Carolina: groaner okc mabucplus kenetic genxnow oklahoma contingency globalism disallowing semblance
# Missouri: parenthackers lovies triplet woodcuts illababy corvallis rarick spaxio clusty pdx
# Colorado: hbg geno offa renter ravenstahl burgh septa pgh wthr sheetz
# Pennsylvania: yhp nicekicks repoed missniyha irmo glittering successfull rangerr photocopies fuddy
# Connecticut: jonsi designologue scrollbar jimbo ravenhill scrollbars kapowski ecpa vespers susannas
# Wisconsin: ellum htown bellagio tme oregonian suitcases dallas austin houston peddler
# Virginia: sext enterta milliseconds istitute keebler copied multiroom fairhope evenius cabinetry
# Oklahoma: nco newswise hoge horay shelle qoute rva twerkas metrix benwell
# Alabama: huskies seatac sounders mallet dc belltown entertonement cmte bellevue seattle
# Iowa: overpasses petfinder chesterfrench neenah prosecute promega negligent badgers rawrock postpaid
#
# ================================================================================
# kNN
# Training:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=10, p=2,
#            weights='uniform')
# trained model
# predicted using model
# accuracy:   0.338
# ================================================================================
# lr
# Training:
# LogisticRegression(C=100000.0, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# trained model
# predicted using model
# accuracy:   0.342
# dimensionality: 10000
# density: 1.000000
# top 10 keywords per class:
# California: midsize perpetually gosocial towleroad deschember berelevant birmingham lifestages dewy planetxbox360
# Georgia: charlaine oneself fujifilm asu barbosa montery tutera comical toor photograp
# Maryland: hoosier eggleston cassius belies bagdad sizzle firsttake examinations timepieces broomfield
# Massachusetts: animate orangeburg gj heisman nfc afc rhymesayers hamel grigsby clarksville
# Minnesota: ct rocketwave1 stamford reaction quiona thnksgng hartford 4x twitjail mindful
# New York: anticipates morristown burnie papago prudential tailspin khartoum bls conneticut heav
# Texas: babycenter latrine luckie invaluable hennepin numer charchian grigsby dundalk bartlet
# Louisiana: newer wbbm stoops reccs stafford plaskett babycenter sano commanders berrian
# North Carolina: oudin lampert urbanusaonline essett tweetlarge telephony bolan lifework macgyver ecotourism
# New Jersey: sarathan barnaul fuhrmann ratenerd des mclean avw kimble moines iowa
# Arizona: socme breesus coer rothwell chimichungas saints lawwwd nola upi origamiwarrior
# Florida: ohso arcs kikky smedes burgaw henceforth unc colussy obx silvana
# Oregon: vols daaance popovers teeing junkfood asu chiles smr deleo tacworldwide
# Tennessee: osan grizzlies fathead therosereport heiser fms nichols 55p typically athelete
# Illinois: fabulus livescience buoys alarmists icumarketing bis mn mwf collegerecruiter photographyblog
# Ohio: preposition midwest meformer kievman kc mizzou twtpoll missouri rayovak rji
# Washington: mammalian minuten djlabels unlv northeastern joga imu varitek kasper kelliher
# Indiana: illistrator twitfam phils suncera dubais laseter cormega coyotes photographyblog freeagent
# Nevada: leav prelim gundy clep stacksss jayhawk koppen legarrette mabel starkville
# Michigan: carolinas adherence beadle raleigh slanted orem paperclip kiffin megachurch sweidan
# Utah: skunks admittedly hornets feherty babi crossmark k2 awhhhh tivation shortstop
# South Carolina: tulsa norman mabucplus kenetic contingency okc semblance disallowing globalism oklahoma
# Missouri: tallahassee nfc pottstown minnesota pdx triplet lansing exploding textron oden
# Colorado: mcgill bensen emeril bethlehem somebodies jann shockey lowertown karza bpt
# Pennsylvania: greenville rangerr successfull onn photocopies metairie statehood yhp epilepsy fuddy
# Connecticut: scrollbar ecpa vespers bejeweled jimbo kapowski ravenhill susannas scrollbars memphis
# Wisconsin: kivi cystic dilfer chattanooga wget indiebizchicks waverly franch staggerin ostomy
# Virginia: istitute milliseconds copied multiroom keebler utah slc fairhope evenius cabinetry
# Oklahoma: nco diversifies tallahassee aamu maryjane misfortunes newswise twidiot stillwater punky
# Alabama: swolen firebaugh wyff defector arghhhhhhh northeastern buoys kdka sumter franchize
# Iowa: badgers tyque shidad violators postpaid kathie rawrock negligent startrek mbta
#
# ================================================================================
# Random forest
# Training:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# trained model
# predicted using model
# accuracy:   0.373
